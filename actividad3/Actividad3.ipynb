# %%
#Importación de pandas, numpy y matplot
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Cargando los archivos del 22 de Diciembre y 22 de Junio
df0 = pd.read_csv('dec22.txt', skiprows=[0,2], sep='\s+')

# %%
df1 = pd.read_csv('jun22.txt', skiprows=[0,2], sep='\s+')

# %%
#Asignar un dataframe
df = pd.DataFrame(df0)

# %%
dg = pd.DataFrame(df1)

# %%
#Preguntando por los tipos de datos
df.dtypes
# Out:
# PRES    float64
# HGHT      int64
# TEMP    float64
# DWPT    float64
# RELH      int64
# MIXR    float64
# DRCT    float64
# SKNT    float64
# THTA    float64
# THTE    float64
# THTV    float64
# dtype: object

# %%
#Muestra de los primeros 5 renglones
df.head()
# Out:
#     PRES  HGHT  TEMP  DWPT  RELH  MIXR   DRCT  SKNT   THTA   THTE   THTV
# 0  997.0   215  -1.5  -5.9    72  2.48   45.0   5.0  271.9  278.8  272.3
# 1  993.0   247  -2.1  -6.6    71  2.36   49.0   5.0  271.6  278.2  272.0
# 2  948.9   610  -4.9  -9.5    70  1.97   90.0  11.0  272.3  277.9  272.6
# 3  946.0   635  -5.1  -9.7    70  1.94   95.0  11.0  272.3  277.9  272.7
# 4  931.0   762  -5.5  -9.6    73  1.99  120.0   9.0  273.2  278.9  273.5

# %%
#Variación de la presión con la altura el 22 de Diciembre
df3 = df[['HGHT','PRES']]
plt.figure(); df3.plot(x='PRES');plt.legend(loc='best') 
plt.title("Variación de la Presión Dec22")
plt.ylabel("Altura(m)")
plt.xlabel("Presión(Pa)")
plt.xlim(0,1000)
plt.grid(True)
plt.show()

# %%
#Variación de la presión con la altura el 22 de Junio
df4 = dg[['HGHT','PRES']]
plt.figure(); df4.plot(x='PRES');plt.legend(loc='best') 
plt.title("Variación de la Presión Dec22")
plt.ylabel("Altura(m)")
plt.xlabel("Presión(Pa)")
plt.xlim(0,1000)
plt.grid(True)
plt.show()

# %%
#Temperatura y Rocío en función de la altura 22 de Diciembre
df5 =df[['TEMP','DWPT']]
plt.figure(); df5.plot()
plt.plot(x=df.HGHT)
plt.title("Temperatura y Temp. del Rocío según la altura Dec22")
plt.xlabel("Altura(m)")
plt.ylabel("Temperatura y Temp. del Rocío (°C)")
plt.show()

# %%
#Temperatura y Rocío en función de la altura 22 de Junio
df6 =dg[['TEMP','DWPT']]
plt.figure(); df6.plot()
plt.plot(x=dg.HGHT)
plt.title("Temperatura y Temp. del Rocío según la altura Jun22")
plt.xlabel("Altura(m)")
plt.ylabel("Temperatura y Temp. del Rocío (°C)")
plt.show()

# %%
#Rapidez de los vientos en nudos 22 de Diciembre
plt.figure(); df.SKNT.plot()
plt.title("Variación de la Rapidez de los Vientos Dec22")
plt.ylabel("Rapidez (m/s)")
plt.ylim(0,200)
plt.grid(True)
plt.show()

# %%
#Rapidez de los vientos en nudos 22 de Junio
plt.figure(); dg.SKNT.plot()
plt.title("Variación de la Rapidez de los Vientos Dec22")
plt.ylabel("Rapidez (m/s)")
plt.ylim(0,200)
plt.grid(True)
plt.show()

# %%
#Humedad Relativa en función de la altura 22 de Diciembre
plt.figure(); df.RELH.plot()
plt.title("Humedad Relativa en función de la altura Dec22")
plt.ylabel("Altura(m)")
plt.grid(True)
plt.show()
